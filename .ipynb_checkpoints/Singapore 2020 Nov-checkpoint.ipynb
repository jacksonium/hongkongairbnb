# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from decimal import Decimal
import datetime
import folium #Longitude and Lattitude mapping.


from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error 

#Import machine learning
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

import seaborn as sns
from itertools import *
import os
import folium
from folium import plugins
from folium.plugins import MarkerCluster #To be able to cluster our individual data points on folium.
from IPython.display import HTML, display

# %%
calendar = pd.read_csv('calendar.csv')
listing = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')
detail_listing = pd.read_csv('listings2.csv') #detailed listings
detail_reviews = pd.read_csv('reviews2.csv') #detailed reviews

# %%
detail_listing.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   69074   https://www.airbnb.com/rooms/69074  20201110180305   2020-11-10
# 1   75083   https://www.airbnb.com/rooms/75083  20201110180305   2020-11-10
# 2  103760  https://www.airbnb.com/rooms/103760  20201110180305   2020-11-10
# 3  104626  https://www.airbnb.com/rooms/104626  20201110180305   2020-11-10
# 4  132773  https://www.airbnb.com/rooms/132773  20201110180305   2020-11-10
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
# 1                      SoHo off Hollywood Road  3B
# 2    Central Centre 5 min walk to/from Central MTR
# 3              Entire Flat - Next to Man Mo Temple
# 4                Fabulous 2 Bdrm Aprt Open kitchen
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
# 1  Located steps from Hollywood road, with new ea...
# 2  Located right in the heart of Central, this 2 ...
# 3  <b>The space</b><br />Situated in one of Hong ...
# 4  Nicely decorated, spacious 2 bedroom apartment...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Sheung Wan neighbourhood is ever changing ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
# 1  https://a0.muscache.com/pictures/2873745/90c15...   304876
# 2  https://a0.muscache.com/pictures/815221/056993...   304876
# 3  https://a0.muscache.com/pictures/1947265/ef01a...   544166
# 4  https://a0.muscache.com/pictures/36936441/e4c1...   304876
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/160139  ...                        10.0
# 1  https://www.airbnb.com/users/show/304876  ...                         9.0
# 2  https://www.airbnb.com/users/show/304876  ...                        10.0
# 3  https://www.airbnb.com/users/show/544166  ...                        10.0
# 4  https://www.airbnb.com/users/show/304876  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                f
# 1                   10.0                 9.0     NaN                f
# 2                   10.0                 9.0     NaN                f
# 3                   10.0                 9.0     NaN                t
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             14                                          10
# 2                             14                                          10
# 3                              1                                           1
# 4                             14                                          10
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            4
# 2                                            4
# 3                                            0
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.13
# 1                                           0              1.94
# 2                                           0              2.38
# 3                                           0              0.12
# 4                                           0              3.12
#
# [5 rows x 74 columns]

# %%
detail_listing.shape
# Out:
# (7226, 74)

# %%
detail_reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       69074  181973  2011-02-14       358597       Chi Yan
# 1       69074  252237  2011-05-05       467243        Doreen
# 2       69074  400484  2011-07-27       696753       Michael
# 3       69074  411022  2011-08-01        40901         Donna
# 4       69074  497498  2011-09-03       341618       Melissa
#
#                                             comments
# 0  Lovely apartment in a great location that quic...
# 1  As a former resident of HK, I can say that Amy...
# 2  I stayed in this Apt for about 12 days. Such a...
# 3  Amy's cute, comfortable apartment is in the he...
# 4  Amy was the perfect host - extremely communica...

# %%
detail_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138963 entries, 0 to 138962
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     138963 non-null  int64
#  1   id             138963 non-null  int64
#  2   date           138963 non-null  object
#  3   reviewer_id    138963 non-null  int64
#  4   reviewer_name  138960 non-null  object
#  5   comments       138846 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 6.4+ MB

# %%
detail_reviews['reviewer_id'].value_counts()#.loc[lambda x : x>10]
# Out:
# 24779930     20
# 8269040      20
# 215818538    18
# 215822237    18
# 5750451      18
#              ..
# 19546893      1
# 150409010     1
# 27213620      1
# 15677237      1
# 192654145     1
# Name: reviewer_id, Length: 128232, dtype: int64

# %%
detail_reviews.groupby('listing_id')['reviewer_id'].value_counts().loc[lambda x : x>5].sort_values(ascending=False)
# Out:
# listing_id  reviewer_id
# 8645263     24779930       20
# 21846948    5750451        14
# 22277128    12542251       13
# 14961766    1323897         7
# 12874832    132544023       7
# 7931794     14765464        7
# 5242151     23693530        7
# 19442489    80616690        6
# 2657448     51864112        6
# 714585      205189686       6
# Name: reviewer_id, dtype: int64

# %%
detail_reviews.loc[detail_reviews['reviewer_id'] == 24779930].sort_values(by=['date'])
# Out:
#        listing_id         id        date  reviewer_id reviewer_name  \
# 44074     8645263   74798629  2016-05-16     24779930        Yujing
# 44077     8645263   77305079  2016-05-31     24779930        Yujing
# 44078     8645263   77517018  2016-06-01     24779930        Yujing
# 44083     8645263   82398401  2016-06-27     24779930        Yujing
# 44084     8645263   82448060  2016-06-27     24779930        Yujing
# 44087     8645263   84020238  2016-07-05     24779930        Yujing
# 44093     8645263   89011729  2016-07-26     24779930        Yujing
# 44094     8645263   89118008  2016-07-26     24779930        Yujing
# 44096     8645263   89687367  2016-07-29     24779930        Yujing
# 44100     8645263   93708085  2016-08-13     24779930        Yujing
# 44103     8645263   95742091  2016-08-20     24779930        Yujing
# 44104     8645263   97297067  2016-08-26     24779930        Yujing
# 44106     8645263   98302855  2016-08-30     24779930        Yujing
# 44107     8645263  102111796  2016-09-16     24779930        Yujing
# 44109     8645263  103919059  2016-09-24     24779930        Yujing
# 44112     8645263  107555032  2016-10-10     24779930        Yujing
# 44116     8645263  111039588  2016-10-29     24779930        Yujing
# 44129     8645263  122197165  2016-12-21     24779930        Yujing
# 44131     8645263  122620574  2016-12-24     24779930        Yujing
# 44153     8645263  135389043  2017-03-04     24779930        Yujing
#
#                                    comments
# 44074                    非常感谢,我们聊天就像朋友一样｡哈哈
# 44077                      真的非常好,我最爱的Sophie
# 44078                      超级好的体验!喜欢跟她一起做面包
# 44083                                    超好
# 44084                       Sophie是我见过最好的房东
# 44087                           好到已经没词了……哈哈
# 44093                          Sophie是家人!哈哈
# 44094                         睡她的地板都好开心哈哈哈哈
# 44096                             就是超级好的朋友!
# 44100       她的耐心和健谈让我在香港有了家一样的安全感.非常感谢这位朋友!
# 44103                              就是非常的幸运!
# 44104                               实在太美好了!
# 44106                 超级可爱的Sophie姐姐,很会做美甲.哈
# 44107                             哈哈哈期待下次见你
# 44109                             太爱Sophie!
# 44112                           我們是非常好的生活夥伴
# 44116                                     棒
# 44129  Sophie is so hard to read…………hahhaha
# 44131                                  棒到无语
# 44153                           We r family

# %% [markdown]
# The same reviewer has left 20 feedback to the same listing! Let's look at one more..

# %%
detail_reviews.loc[detail_reviews['reviewer_id'] == 5750451].sort_values(by=['date'])
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 19555      4362354  348974810  2018-11-16      5750451       Stephan
# 102887    21846948  351485627  2018-11-23      5750451       Stephan
# 102894    21846948  360520768  2018-12-21      5750451       Stephan
# 102896    21846948  367059930  2019-01-04      5750451       Stephan
# 102900    21846948  402288232  2019-01-18      5750451       Stephan
# 102903    21846948  406786391  2019-01-31      5750451       Stephan
# 102906    21846948  412234369  2019-02-15      5750451       Stephan
# 103080    21851372  423720875  2019-03-15      5750451       Stephan
# 102910    21846948  432446756  2019-04-04      5750451       Stephan
# 13420      2393133  447123095  2019-05-03      5750451       Stephan
# 102916    21846948  453846640  2019-05-17      5750451       Stephan
# 92253     19728224  453860531  2019-05-17      5750451       Stephan
# 102918    21846948  457358420  2019-05-24      5750451       Stephan
# 102919    21846948  461100911  2019-05-31      5750451       Stephan
# 102923    21846948  477268668  2019-06-28      5750451       Stephan
# 102926    21846948  486053427  2019-07-12      5750451       Stephan
# 102927    21846948  490575961  2019-07-19      5750451       Stephan
# 102931    21846948  500249776  2019-08-02      5750451       Stephan
#
#                                                  comments
# 19555   Very pleasant stay in North Point. Clean room ...
# 102887  Very nice unit - very clean, relatively spacio...
# 102894  This is my third stay at Sangsoon's place and ...
# 102896  Again a very pleasant stay at Sangsoon's place...
# 102900  I'm by now a regular Sangsoon's place - apprec...
# 102903  Centrally located, sparkling clean, great amen...
# 102906  I'm by now a regular - still appreciate the gr...
# 103080  I am a regular guest at the Possession street ...
# 102910  Consistently very clean with lots of helpful a...
# 13420   Spacious apartment by HK standards and ha all ...
# 102916  I'm a regular at Sangsoon's Unit B by now duri...
# 92253   This is a very spacious apartment by Hong Kong...
# 102918  Am a regular at Sangsoon's place Unit B - very...
# 102919  Centrally located studio with all the amenitie...
# 102923  I'm a regular at Lucky Unit B - great location...
# 102926  Centrally located, sparkling clean with all th...
# 102927  Centrally located, sparkling clean with all th...
# 102931    Thanks a lot for the great stay - will be back!

# %%
#calendar.info()
calendar.head()
# Out:
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0     1907254  2020-11-10         t  $1,124.00      $1,124.00              90
# 1     1907254  2020-11-11         f  $1,124.00      $1,124.00              90
# 2     1907254  2020-11-12         f  $1,124.00      $1,124.00              90
# 3     1907254  2020-11-13         f  $1,124.00      $1,124.00              90
# 4     1907254  2020-11-14         f  $1,124.00      $1,124.00              90
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637490 entries, 0 to 2637489
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 140.9+ MB

# %% [markdown]
# Let's clean some data on calendar dataset

# %%
calendar.shape
# Out:
# (2637490, 7)

# %%
calendar[calendar['price'] > calendar['adjusted_price']]
# Out:
#          listing_id        date available    price adjusted_price  \
# 10297        911684  2020-11-10         f  $296.00        $266.00
# 10298        911684  2020-11-11         f  $308.00        $277.00
# 10299        911684  2020-11-12         f  $228.00        $205.00
# 10300        911684  2020-11-13         t  $228.00        $210.00
# 10301        911684  2020-11-14         t  $228.00        $210.00
# ...             ...         ...       ...      ...            ...
# 2628102    46045630  2021-11-05         t  $584.00        $467.00
# 2628103    46045630  2021-11-06         t  $584.00        $467.00
# 2628104    46045630  2021-11-07         t  $584.00        $467.00
# 2628105    46045630  2021-11-08         t  $584.00        $467.00
# 2628106    46045630  2021-11-09         t  $584.00        $467.00
#
#          minimum_nights  maximum_nights
# 10297                15              90
# 10298                15              90
# 10299                15              90
# 10300                15              90
# 10301                15              90
# ...                 ...             ...
# 2628102               1            1125
# 2628103               1            1125
# 2628104               1            1125
# 2628105               1            1125
# 2628106               1            1125
#
# [64722 rows x 7 columns]

# %%
#convert date into date datatype
calendar['date'] = pd.to_datetime(calendar['date'])

#convert prices into numbers
calendar['price'] = pd.to_numeric(calendar['price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')
calendar['adjusted_price'] = pd.to_numeric(calendar['adjusted_price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')

#convert available into boolean
d = {'t': True, 'f': False}
calendar['available'] = calendar['available'].map(d)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637490 entries, 0 to 2637489
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       bool
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(3)
# memory usage: 123.3 MB

# %%
calendar.tail()
# Out:
#          listing_id       date  available  price  adjusted_price  \
# 2637485    46284335 2021-11-05       True  220.0           220.0
# 2637486    46284335 2021-11-06       True  220.0           220.0
# 2637487    46284335 2021-11-07       True  220.0           220.0
# 2637488    46284335 2021-11-08       True  220.0           220.0
# 2637489    46284335 2021-11-09       True  220.0           220.0
#
#          minimum_nights  maximum_nights
# 2637485               1            1125
# 2637486               1            1125
# 2637487               1            1125
# 2637488               1            1125
# 2637489               1            1125

# %%
#filter calendar minimum_nights for less than 28 days > short term rental
calendar[calendar['minimum_nights'] < 28]['listing_id'].unique().size
# Out:
# 4916

# %%
short_term = (calendar[calendar['minimum_nights'] < 28]['listing_id'].unique().size)/7226
short_term
# Out:
# 0.6803210628286742

# %% [markdown]
# There are over 68% airbnb lisings in Hong Kong offer short term rentals that is 28 days or less. => possible illegal listing!
#
# How do we find out?! There is a list of licensed guest house in HK https://www.hadla.gov.hk/filemanager/en/docs/list_licensed_guesthouse_eng.pdf
#
# However we dont have the address for airbnb dataset, perhaps do something with longitude/latitude? But then the government licsensed guesthouse have no longitude/latitude coordinates...
#
# Maybe save it for some other execuse when I have time...

# %%
calendar_test = calendar.groupby('listing_id')['date'].count().reset_index()
calendar_test
# Out:
#       listing_id  date
# 0          69074   365
# 1          75083   365
# 2         103760   365
# 3         104626   365
# 4         132773   365
# ...          ...   ...
# 7221    46304295   365
# 7222    46318909   365
# 7223    46323391   365
# 7224    46342535   365
# 7225    46343317   365
#
# [7226 rows x 2 columns]

# %%
calendar_test['date'].value_counts()
# Out:
# 365    7226
# Name: date, dtype: int64

# %% [markdown]
# There are 365 rows for each listing.

# %%
#checking the available column... see how many non null
calendar_test = calendar.groupby('available')['price'].value_counts()
#calendar_test = calendar.groupby('available')['price'].count().reset_index()

calendar_test
# Out:
# available  price
# False      350.0      24595
#            500.0      23289
#            400.0      22285
#            450.0      20319
#            300.0      17488
#                       ...
# True       4510.0         1
#            4556.0         1
#            4616.0         1
#            5142.0         1
#            10500.0        1
# Name: price, Length: 4802, dtype: int64

# %%
calendar['available'].value_counts()/calendar.shape[0]
# Out:
# True     0.698499
# False    0.301501
# Name: available, dtype: float64

# %% [markdown]
# 70% of the listings are marked available. Either the other 30% are booked or owners have taken it off the market?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()

#calendar_test_mean = calendar1[(calendar1['date'] > from_ts) & (calendar1['date'] < to_ts) & (calendar1['available'] == True)]
#calendar_test_mean = calendar1[(calendar1['available'] == True)]
calendar_test_mean = calendar1

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['adjusted_price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.adjusted_price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# What happen if we exclude those that are unavailable?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()


calendar_test_mean = calendar1[(calendar1['available'] == True)]

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['adjusted_price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.adjusted_price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# what happened if i plot those that are unavailable?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()

calendar_test_mean = calendar1[(calendar1['available'] == False)]

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['adjusted_price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.adjusted_price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# Let's take a look at the listing data.

# %%
detail_listing.head(1)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  69074  https://www.airbnb.com/rooms/69074  20201110180305   2020-11-10
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/160139  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.13
#
# [1 rows x 74 columns]

# %% [markdown]
# How many airbnb listings in Hong Kong?

# %%
detail_listing.shape
# Out:
# (7226, 74)

# %%
detail_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7226 non-null   int64
#  1   listing_url                                   7226 non-null   object
#  2   scrape_id                                     7226 non-null   int64
#  3   last_scraped                                  7226 non-null   object
#  4   name                                          7225 non-null   object
#  5   description                                   6844 non-null   object
#  6   neighborhood_overview                         3255 non-null   object
#  7   picture_url                                   7226 non-null   object
#  8   host_id                                       7226 non-null   int64
#  9   host_url                                      7226 non-null   object
#  10  host_name                                     7226 non-null   object
#  11  host_since                                    7226 non-null   object
#  12  host_location                                 7210 non-null   object
#  13  host_about                                    4677 non-null   object
#  14  host_response_time                            6111 non-null   object
#  15  host_response_rate                            6111 non-null   object
#  16  host_acceptance_rate                          5746 non-null   object
#  17  host_is_superhost                             7226 non-null   object
#  18  host_thumbnail_url                            7226 non-null   object
#  19  host_picture_url                              7226 non-null   object
#  20  host_neighbourhood                            6027 non-null   object
#  21  host_listings_count                           7226 non-null   int64
#  22  host_total_listings_count                     7226 non-null   int64
#  23  host_verifications                            7226 non-null   object
#  24  host_has_profile_pic                          7226 non-null   object
#  25  host_identity_verified                        7226 non-null   object
#  26  neighbourhood                                 3255 non-null   object
#  27  neighbourhood_cleansed                        7226 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      7226 non-null   float64
#  30  longitude                                     7226 non-null   float64
#  31  property_type                                 7226 non-null   object
#  32  room_type                                     7226 non-null   object
#  33  accommodates                                  7226 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                7205 non-null   object
#  36  bedrooms                                      5924 non-null   float64
#  37  beds                                          7077 non-null   float64
#  38  amenities                                     7226 non-null   object
#  39  price                                         7226 non-null   object
#  40  minimum_nights                                7226 non-null   int64
#  41  maximum_nights                                7226 non-null   int64
#  42  minimum_minimum_nights                        7226 non-null   int64
#  43  maximum_minimum_nights                        7226 non-null   int64
#  44  minimum_maximum_nights                        7226 non-null   int64
#  45  maximum_maximum_nights                        7226 non-null   int64
#  46  minimum_nights_avg_ntm                        7226 non-null   float64
#  47  maximum_nights_avg_ntm                        7226 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              7226 non-null   object
#  50  availability_30                               7226 non-null   int64
#  51  availability_60                               7226 non-null   int64
#  52  availability_90                               7226 non-null   int64
#  53  availability_365                              7226 non-null   int64
#  54  calendar_last_scraped                         7226 non-null   object
#  55  number_of_reviews                             7226 non-null   int64
#  56  number_of_reviews_ltm                         7226 non-null   int64
#  57  number_of_reviews_l30d                        7226 non-null   int64
#  58  first_review                                  3992 non-null   object
#  59  last_review                                   3992 non-null   object
#  60  review_scores_rating                          3896 non-null   float64
#  61  review_scores_accuracy                        3896 non-null   float64
#  62  review_scores_cleanliness                     3896 non-null   float64
#  63  review_scores_checkin                         3896 non-null   float64
#  64  review_scores_communication                   3896 non-null   float64
#  65  review_scores_location                        3896 non-null   float64
#  66  review_scores_value                           3896 non-null   float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              7226 non-null   object
#  69  calculated_host_listings_count                7226 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7226 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7226 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7226 non-null   int64
#  73  reviews_per_month                             3992 non-null   float64
# dtypes: float64(18), int64(23), object(33)
# memory usage: 4.1+ MB

# %%
filtered_listing = detail_listing[['property_type', 'room_type', 'accommodates', 'neighbourhood_cleansed', 'review_scores_value', 'number_of_reviews', 
                                   'bedrooms', 'price', 'longitude', 'latitude']].copy()
#convert prices into numbers
filtered_listing['price'] = pd.to_numeric(filtered_listing['price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')

filtered_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   property_type           7226 non-null   object
#  1   room_type               7226 non-null   object
#  2   accommodates            7226 non-null   int64
#  3   neighbourhood_cleansed  7226 non-null   object
#  4   review_scores_value     3896 non-null   float64
#  5   number_of_reviews       7226 non-null   int64
#  6   bedrooms                5924 non-null   float64
#  7   price                   7226 non-null   float64
#  8   longitude               7226 non-null   float64
#  9   latitude                7226 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 564.7+ KB

# %%
filtered_listing
# Out:
#               property_type        room_type  accommodates  \
# 0          Entire apartment  Entire home/apt             3
# 1          Entire apartment  Entire home/apt             3
# 2          Entire apartment  Entire home/apt             6
# 3          Entire apartment  Entire home/apt             2
# 4          Entire apartment  Entire home/apt             6
# ...                     ...              ...           ...
# 7221       Entire apartment  Entire home/apt             4
# 7222  Shared room in hostel      Shared room             3
# 7223       Entire apartment  Entire home/apt             2
# 7224       Entire apartment  Entire home/apt             2
# 7225  Private room in house     Private room             2
#
#      neighbourhood_cleansed  review_scores_value  number_of_reviews  bedrooms  \
# 0         Central & Western                  9.0                134       1.0
# 1         Central & Western                  9.0                229       NaN
# 2         Central & Western                  9.0                272       2.0
# 3         Central & Western                  9.0                 14       1.0
# 4         Central & Western                 10.0                210       2.0
# ...                     ...                  ...                ...       ...
# 7221               Wan Chai                  NaN                  0       1.0
# 7222              Yuen Long                  NaN                  0       NaN
# 7223      Central & Western                  NaN                  0       1.0
# 7224      Central & Western                  NaN                  0       1.0
# 7225           Kowloon City                  NaN                  0       1.0
#
#        price   longitude   latitude
# 0     1270.0  114.150180  22.283520
# 1      403.0  114.148390  22.283980
# 2      690.0  114.155700  22.284070
# 3     2575.0  114.148340  22.282220
# 4      845.0  114.144940  22.288680
# ...      ...         ...        ...
# 7221  1308.0  114.170760  22.277280
# 7222    52.0  114.063962  22.520766
# 7223   750.0  114.128539  22.279915
# 7224   400.0  114.142931  22.285564
# 7225   289.0  114.178990  22.317913
#
# [7226 rows x 10 columns]

# %% [markdown]
# Do we have more apartment or room on airbnbn in Hong Kong?

# %%
filtered_listing['property_type'].value_counts()
# Out:
# Private room in apartment      2354
# Entire apartment               1720
# Private room in condominium     356
# Entire condominium              338
# Entire serviced apartment       306
#                                ...
# Private room in minsu             1
# Private room in island            1
# Shared room in castle             1
# Castle                            1
# Farm stay                         1
# Name: property_type, Length: 77, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.xticks(rotation=90)
sns.countplot(x=(filtered_listing)[('property_type')], order = filtered_listing['property_type'].value_counts().index)
plt.show()

# %% [markdown]
# Lets look at 'room_type'..

# %%
filtered_listing['room_type'].value_counts()
# Out:
# Private room       3975
# Entire home/apt    2602
# Shared room         459
# Hotel room          190
# Name: room_type, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.xticks(rotation=90)
sns.countplot(x=(filtered_listing)[('room_type')], order = filtered_listing['room_type'].value_counts().index)
plt.show()

# %%
(filtered_listing['neighbourhood_cleansed'].value_counts())/(filtered_listing['neighbourhood_cleansed'].count())
# Out:
# Yau Tsim Mong        0.433020
# Wan Chai             0.202325
# Central & Western    0.135068
# Kowloon City         0.042070
# Islands              0.039718
# Eastern              0.036812
# Sham Shui Po         0.023665
# North                0.021450
# Yuen Long            0.020066
# Sai Kung             0.011210
# Sha Tin              0.008027
# Southern             0.006089
# Tsuen Wan            0.004428
# Tuen Mun             0.004152
# Kwun Tong            0.004013
# Kwai Tsing           0.003460
# Tai Po               0.003183
# Wong Tai Sin         0.001246
# Name: neighbourhood_cleansed, dtype: float64

# %%
plt.figure(figsize=(20,20))
plt.xticks(rotation=90)
sns.countplot(x=(filtered_listing)[('neighbourhood_cleansed')], hue= filtered_listing['room_type'], order = filtered_listing['neighbourhood_cleansed'].value_counts().index)
plt.show()

# %%
df_plot = filtered_listing.groupby(['room_type', 'neighbourhood_cleansed']).size().reset_index().pivot(columns='room_type', index='neighbourhood_cleansed', values=0)
df_plot = df_plot.fillna(0)

df_plot['total'] = df_plot['Private room'] + df_plot['Entire home/apt'] + df_plot['Shared room'] + df_plot['Hotel room']
df_plot = df_plot.sort_values(by=['total'], ascending = False).drop(['total'], axis=1)
df_plot.plot(kind='bar', stacked=True)
#df_plot
# Out:
# <AxesSubplot:xlabel='neighbourhood_cleansed'>

# %%
neighbourhood_count = filtered_listing.groupby('neighbourhood_cleansed').property_type.count().sort_values(ascending=False).reset_index()
neighbourhood_count
# Out:
#    neighbourhood_cleansed  property_type
# 0           Yau Tsim Mong           3129
# 1                Wan Chai           1462
# 2       Central & Western            976
# 3            Kowloon City            304
# 4                 Islands            287
# 5                 Eastern            266
# 6            Sham Shui Po            171
# 7                   North            155
# 8               Yuen Long            145
# 9                Sai Kung             81
# 10                Sha Tin             58
# 11               Southern             44
# 12              Tsuen Wan             32
# 13               Tuen Mun             30
# 14              Kwun Tong             29
# 15             Kwai Tsing             25
# 16                 Tai Po             23
# 17           Wong Tai Sin              9

# %% [markdown]
# The following plot also indicate where these listings are concentrated.

# %%
#Creates a map of Hong Kong.
m = folium.Map(location=[22.34, 114.1], zoom_start = 11)
m.save('index.html')


#Takes the latitude and longitude coordinates and zips them into a form to be plotted.
lat = pd.to_numeric(filtered_listing['latitude'], errors = 'coerce')
lon = pd.to_numeric(filtered_listing['longitude'], errors = 'coerce')

#Zip togethers each list of latitude and longitude coordinates. 
lat_lon = list(zip(lat,lon))


mc = MarkerCluster().add_to(m)
for i in range(0,len(filtered_listing)):
    folium.Marker(location=lat_lon[i]).add_to(mc)

m.save('index.html')
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filtered_listing.hist()
# Out:
# array([[<AxesSubplot:title={'center':'accommodates'}>,
#         <AxesSubplot:title={'center':'review_scores_value'}>,
#         <AxesSubplot:title={'center':'number_of_reviews'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'longitude'}>],
#        [<AxesSubplot:title={'center':'latitude'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
filtered_listing2 = pd.get_dummies(filtered_listing, columns=["room_type", "neighbourhood_cleansed"], prefix=["room_type", "neighbourhood"])

plt.figure(figsize = (16,16))
sns.heatmap(filtered_listing2.corr(), annot=True, fmt=".2f");

# %%
test = filtered_listing.dropna()

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3264 entries, 0 to 7173
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   property_type           3264 non-null   object
#  1   room_type               3264 non-null   object
#  2   accommodates            3264 non-null   int64
#  3   neighbourhood_cleansed  3264 non-null   object
#  4   review_scores_value     3264 non-null   float64
#  5   number_of_reviews       3264 non-null   int64
#  6   bedrooms                3264 non-null   float64
#  7   price                   3264 non-null   float64
#  8   longitude               3264 non-null   float64
#  9   latitude                3264 non-null   float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 280.5+ KB

# %%
#Split into explanatory and response variables

X = test.drop(['price','property_type','room_type', 'neighbourhood_cleansed'], axis=1)
y = test['price']


#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict and score the model
y_train_preds = lm_model.predict(X_train) 
y_test_preds = lm_model.predict(X_test) 


train_score = r2_score(y_train,y_train_preds)
test_score = r2_score(y_test, y_test_preds)#r2_score

print('Linear Regression r2 score => train: %.3f, test: %.3f' % (
        train_score,
        test_score))
# Out:
# Linear Regression r2 score => train: 0.039, test: 0.041

# %%
filtered_listing2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   property_type                    7226 non-null   object
#  1   accommodates                     7226 non-null   int64
#  2   review_scores_value              3896 non-null   float64
#  3   number_of_reviews                7226 non-null   int64
#  4   bedrooms                         5924 non-null   float64
#  5   price                            7226 non-null   float64
#  6   longitude                        7226 non-null   float64
#  7   latitude                         7226 non-null   float64
#  8   room_type_Entire home/apt        7226 non-null   uint8
#  9   room_type_Hotel room             7226 non-null   uint8
#  10  room_type_Private room           7226 non-null   uint8
#  11  room_type_Shared room            7226 non-null   uint8
#  12  neighbourhood_Central & Western  7226 non-null   uint8
#  13  neighbourhood_Eastern            7226 non-null   uint8
#  14  neighbourhood_Islands            7226 non-null   uint8
#  15  neighbourhood_Kowloon City       7226 non-null   uint8
#  16  neighbourhood_Kwai Tsing         7226 non-null   uint8
#  17  neighbourhood_Kwun Tong          7226 non-null   uint8
#  18  neighbourhood_North              7226 non-null   uint8
#  19  neighbourhood_Sai Kung           7226 non-null   uint8
#  20  neighbourhood_Sha Tin            7226 non-null   uint8
#  21  neighbourhood_Sham Shui Po       7226 non-null   uint8
#  22  neighbourhood_Southern           7226 non-null   uint8
#  23  neighbourhood_Tai Po             7226 non-null   uint8
#  24  neighbourhood_Tsuen Wan          7226 non-null   uint8
#  25  neighbourhood_Tuen Mun           7226 non-null   uint8
#  26  neighbourhood_Wan Chai           7226 non-null   uint8
#  27  neighbourhood_Wong Tai Sin       7226 non-null   uint8
#  28  neighbourhood_Yau Tsim Mong      7226 non-null   uint8
#  29  neighbourhood_Yuen Long          7226 non-null   uint8
# dtypes: float64(5), int64(2), object(1), uint8(22)
# memory usage: 607.0+ KB

# %%
filtered_listing2['review_scores_value'] = filtered_listing2['review_scores_value'].fillna(0)
filtered_listing2['bedrooms'] = filtered_listing2['bedrooms'].fillna(0)

filtered_listing2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   property_type                    7226 non-null   object
#  1   accommodates                     7226 non-null   int64
#  2   review_scores_value              7226 non-null   float64
#  3   number_of_reviews                7226 non-null   int64
#  4   bedrooms                         7226 non-null   float64
#  5   price                            7226 non-null   float64
#  6   longitude                        7226 non-null   float64
#  7   latitude                         7226 non-null   float64
#  8   room_type_Entire home/apt        7226 non-null   uint8
#  9   room_type_Hotel room             7226 non-null   uint8
#  10  room_type_Private room           7226 non-null   uint8
#  11  room_type_Shared room            7226 non-null   uint8
#  12  neighbourhood_Central & Western  7226 non-null   uint8
#  13  neighbourhood_Eastern            7226 non-null   uint8
#  14  neighbourhood_Islands            7226 non-null   uint8
#  15  neighbourhood_Kowloon City       7226 non-null   uint8
#  16  neighbourhood_Kwai Tsing         7226 non-null   uint8
#  17  neighbourhood_Kwun Tong          7226 non-null   uint8
#  18  neighbourhood_North              7226 non-null   uint8
#  19  neighbourhood_Sai Kung           7226 non-null   uint8
#  20  neighbourhood_Sha Tin            7226 non-null   uint8
#  21  neighbourhood_Sham Shui Po       7226 non-null   uint8
#  22  neighbourhood_Southern           7226 non-null   uint8
#  23  neighbourhood_Tai Po             7226 non-null   uint8
#  24  neighbourhood_Tsuen Wan          7226 non-null   uint8
#  25  neighbourhood_Tuen Mun           7226 non-null   uint8
#  26  neighbourhood_Wan Chai           7226 non-null   uint8
#  27  neighbourhood_Wong Tai Sin       7226 non-null   uint8
#  28  neighbourhood_Yau Tsim Mong      7226 non-null   uint8
#  29  neighbourhood_Yuen Long          7226 non-null   uint8
# dtypes: float64(5), int64(2), object(1), uint8(22)
# memory usage: 607.0+ KB

# %%
#Split into explanatory and response variables

X = filtered_listing2.drop(['price','property_type'], axis=1)
y = filtered_listing2['price']


#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict and score the model
y_train_preds = lm_model.predict(X_train) 
y_test_preds = lm_model.predict(X_test) 


train_score = r2_score(y_train,y_train_preds)
test_score = r2_score(y_test, y_test_preds)#r2_score

print('Linear Regression r2 score => train: %.3f, test: %.3f' % (
        train_score,
        test_score))
# Out:
# Linear Regression r2 score => train: 0.046, test: 0.024

# %% [markdown]
# trying more variables....

# %%
filtered_listing_long = detail_listing[['price',
#'bedrooms',
#'host_is_superhost',
#'host_listings_count',
#'host_total_listings_count',
#'neighbourhood_cleansed',
#'latitude',
#'longitude',
#'room_type',
'accommodates',
'number_of_reviews',
'number_of_reviews_ltm',
'number_of_reviews_l30d',
#'review_scores_rating',
#'review_scores_accuracy',
#'review_scores_cleanliness',
#'review_scores_checkin',
#'review_scores_communication',
#'review_scores_location',
#'review_scores_value',
#'instant_bookable',
#'calculated_host_listings_count',
#'calculated_host_listings_count_entire_homes',
#'calculated_host_listings_count_private_rooms',
#'calculated_host_listings_count_shared_rooms',
'reviews_per_month'
                                       ]].copy()



#convert prices into numbers
filtered_listing_long['price'] = pd.to_numeric(filtered_listing_long['price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')

filtered_listing_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   price                   7226 non-null   float64
#  1   accommodates            7226 non-null   int64
#  2   number_of_reviews       7226 non-null   int64
#  3   number_of_reviews_ltm   7226 non-null   int64
#  4   number_of_reviews_l30d  7226 non-null   int64
#  5   reviews_per_month       3992 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 338.8 KB

# %%
filtered_listing_long = filtered_listing_long.dropna()

#filtered_listing_long = filtered_listing_long.fillna(0)

#convert available into boolean
#filtered_listing_long['host_is_superhost'] = filtered_listing_long['host_is_superhost'].map(d)
#filtered_listing_long['instant_bookable'] = filtered_listing_long['instant_bookable'].map(d)
#filtered_listing_long = pd.get_dummies(filtered_listing_long, columns=["room_type", "neighbourhood_cleansed"], prefix=["room_type", "neighbourhood"])


filtered_listing_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3992 entries, 0 to 7173
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   price                   3992 non-null   float64
#  1   accommodates            3992 non-null   int64
#  2   number_of_reviews       3992 non-null   int64
#  3   number_of_reviews_ltm   3992 non-null   int64
#  4   number_of_reviews_l30d  3992 non-null   int64
#  5   reviews_per_month       3992 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 218.3 KB

# %%
#Split into explanatory and response variables

X = filtered_listing_long.drop(['price'], axis=1)
y = filtered_listing_long['price']


#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict and score the model
y_train_preds = lm_model.predict(X_train) 
y_test_preds = lm_model.predict(X_test) 


train_score = r2_score(y_train,y_train_preds)
test_score = r2_score(y_test, y_test_preds)#r2_score

print('Linear Regression r2 score => train: %.3f, test: %.3f' % (
        train_score,
        test_score))
# Out:
# Linear Regression r2 score => train: 0.018, test: 0.058

# %%
coeff_pd = pd.DataFrame(lm_model.coef_,X_train.columns,columns=['Coefficient'])
coeff_pd
# Out:
#                         Coefficient
# accommodates             100.309126
# number_of_reviews         -0.640798
# number_of_reviews_ltm     -4.811358
# number_of_reviews_l30d    72.160346
# reviews_per_month        -36.206654

# %%
#I will train Random Forest Regressor model
forest = RandomForestRegressor(n_estimators=100, 
                               criterion='mse', 
                               random_state=42, 
                               n_jobs=-1)
forest.fit(X_train, y_train.squeeze())

#calculate scores for the model
y_train_preds = forest.predict(X_train)
y_test_preds = forest.predict(X_test)

print('Random Forest MSE train: %.3f, test: %.3f' % (
        mean_squared_error(y_train, y_train_preds),
        mean_squared_error(y_test, y_test_preds)))
print('Random Forest R^2 train: %.3f, test: %.3f' % (
        r2_score(y_train, y_train_preds),
        r2_score(y_test, y_test_preds)))
# Out:
# Random Forest MSE train: 1921373.892, test: 2679879.182
# Random Forest R^2 train: 0.454, test: -1.166
