# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from decimal import Decimal
import datetime
import folium #Longitude and Lattitude mapping.
from sklearn.preprocessing import LabelEncoder, OneHotEncoder #We don't this in the analysis I am currently showing.
from sklearn.linear_model import LinearRegression #We don't this in the analysis I am currently showing.
import seaborn as sns
from itertools import *
import os
import folium
from folium import plugins
from folium.plugins import MarkerCluster #To be able to cluster our individual data points on folium.
from IPython.display import HTML, display

# %%
calendar = pd.read_csv('calendar.csv')
listing = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')
detail_listing = pd.read_csv('listings2.csv') #detailed listings
detail_reviews = pd.read_csv('reviews2.csv') #detailed reviews

# %%
reviews.head()
# Out:
#    listing_id        date
# 0       69074  2011-02-14
# 1       69074  2011-05-05
# 2       69074  2011-07-27
# 3       69074  2011-08-01
# 4       69074  2011-09-03

# %%
listing.head()
# Out:
#        id                                             name  host_id host_name  \
# 0   69074  Beautiful oasis of plants & art @ best location   160139       Amy
# 1   75083                      SoHo off Hollywood Road  3B   304876     Brend
# 2  103760    Central Centre 5 min walk to/from Central MTR   304876     Brend
# 3  104626              Entire Flat - Next to Man Mo Temple   544166    Celine
# 4  132773                Fabulous 2 Bdrm Aprt Open kitchen   304876     Brend
#
#    neighbourhood_group      neighbourhood  latitude  longitude  \
# 0                  NaN  Central & Western  22.28352  114.15018
# 1                  NaN  Central & Western  22.28398  114.14839
# 2                  NaN  Central & Western  22.28407  114.15570
# 3                  NaN  Central & Western  22.28222  114.14834
# 4                  NaN  Central & Western  22.28868  114.14494
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   1270               3                134  2020-03-24
# 1  Entire home/apt    403              14                229  2020-04-18
# 2  Entire home/apt    690               2                272  2020-07-07
# 3  Entire home/apt   2575               1                 14  2012-02-06
# 4  Entire home/apt    845               2                210  2020-10-10
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               1.13                               1               177
# 1               1.94                              14                 2
# 2               2.38                              14               364
# 3               0.12                               1               365
# 4               3.12                              14                 0

# %%
listing.shape
# Out:
# (7226, 16)

# %%
#calendar.info()
calendar.head()
# Out:
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0     1907254  2020-11-10         t  $1,124.00      $1,124.00              90
# 1     1907254  2020-11-11         f  $1,124.00      $1,124.00              90
# 2     1907254  2020-11-12         f  $1,124.00      $1,124.00              90
# 3     1907254  2020-11-13         f  $1,124.00      $1,124.00              90
# 4     1907254  2020-11-14         f  $1,124.00      $1,124.00              90
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637490 entries, 0 to 2637489
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 140.9+ MB

# %% [markdown]
# Let's clean some data on calendar dataset

# %%
#convert date into date datatype
calendar['date'] = pd.to_datetime(calendar['date'])

#convert prices into numbers
calendar['price'] = pd.to_numeric(calendar['price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')
calendar['adjusted_price'] = pd.to_numeric(calendar['adjusted_price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), errors='coerce')

#convert available into boolean
d = {'t': True, 'f': False}
calendar['available'] = calendar['available'].map(d)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637490 entries, 0 to 2637489
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       bool
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(3)
# memory usage: 123.3 MB

# %%
calendar.tail()
# Out:
#          listing_id       date  available  price  adjusted_price  \
# 2637485    46284335 2021-11-05       True  220.0           220.0
# 2637486    46284335 2021-11-06       True  220.0           220.0
# 2637487    46284335 2021-11-07       True  220.0           220.0
# 2637488    46284335 2021-11-08       True  220.0           220.0
# 2637489    46284335 2021-11-09       True  220.0           220.0
#
#          minimum_nights  maximum_nights
# 2637485               1            1125
# 2637486               1            1125
# 2637487               1            1125
# 2637488               1            1125
# 2637489               1            1125

# %%
#filter calendar minimum_nights for less than 28 days => short term rental
calendar[calendar['minimum_nights'] < 28]['listing_id'].unique().size
# Out:
# 4916

# %%
short_term = (calendar[calendar['minimum_nights'] < 28]['listing_id'].unique().size)/7226
short_term
# Out:
# 0.6803210628286742

# %% [markdown]
# There are over 68% airbnb lisings in Hong Kong offer short term rentals that is 28 days or less. => possible illegal listing!
#
# How do we find out?! There is a list of licensed guest house in HK https://www.hadla.gov.hk/filemanager/en/docs/list_licensed_guesthouse_eng.pdf
#
# However we dont have the address for airbnb dataset, perhaps do something with longitude/latitude? But then the government licsensed guesthouse have no longitude/latitude coordinates...
#
# Maybe save it for some other execuse when I have time...

# %%
calendar_test = calendar.groupby('listing_id')['date'].count().reset_index()
calendar_test
#calendar_test['date'].value_counts()
# Out:
#       listing_id  date
# 0          69074   365
# 1          75083   365
# 2         103760   365
# 3         104626   365
# 4         132773   365
# ...          ...   ...
# 7221    46304295   365
# 7222    46318909   365
# 7223    46323391   365
# 7224    46342535   365
# 7225    46343317   365
#
# [7226 rows x 2 columns]

# %% [markdown]
# There are 365 rows for each listing.

# %%
#checking the available column... see how many non null
calendar_test = calendar.groupby('available')['price'].value_counts()
#calendar_test = calendar.groupby('available')['price'].count().reset_index()

calendar_test
# Out:
# available  price
# False      350.0      24595
#            500.0      23289
#            400.0      22285
#            450.0      20319
#            300.0      17488
#                       ...
# True       4510.0         1
#            4556.0         1
#            4616.0         1
#            5142.0         1
#            10500.0        1
# Name: price, Length: 4802, dtype: int64

# %%
calendar['available'].value_counts()/calendar.shape[0]
# Out:
# True     0.698499
# False    0.301501
# Name: available, dtype: float64

# %% [markdown]
# 70% of the listings are marked available. Either the other 30% are booked or owners have taken it off the market?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()

#calendar_test_mean = calendar1[(calendar1['date'] > from_ts) & (calendar1['date'] < to_ts) & (calendar1['available'] == True)]
#calendar_test_mean = calendar1[(calendar1['available'] == True)]
calendar_test_mean = calendar1

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# What happen if we exclude those that are unavailable?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()


calendar_test_mean = calendar1[(calendar1['available'] == True)]

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# what happened if i plot those that are unavailable?

# %%
# Lets find out if there are a price trend for the upcoming year.
calendar1 = calendar.dropna()

calendar_test_mean = calendar1[(calendar1['available'] == False)]

# Taking average
calendar_test_mean = calendar_test_mean.groupby('date')['price'].mean().reset_index()

# plot avg listings prices over time.
plt.figure(figsize=(15, 8))
plt.plot(calendar_test_mean.date, calendar_test_mean.price, color='b', marker='.', linewidth=0.9)
plt.title("Forward average listing price")
plt.xlabel('Date')
plt.ylabel('Average listing price')
plt.grid()

# %% [markdown]
# Let's take a look at the listing data.

# %%
detail_listing.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   69074   https://www.airbnb.com/rooms/69074  20201110180305   2020-11-10
# 1   75083   https://www.airbnb.com/rooms/75083  20201110180305   2020-11-10
# 2  103760  https://www.airbnb.com/rooms/103760  20201110180305   2020-11-10
# 3  104626  https://www.airbnb.com/rooms/104626  20201110180305   2020-11-10
# 4  132773  https://www.airbnb.com/rooms/132773  20201110180305   2020-11-10
#
#                                               name  \
# 0  Beautiful oasis of plants & art @ best location
# 1                      SoHo off Hollywood Road  3B
# 2    Central Centre 5 min walk to/from Central MTR
# 3              Entire Flat - Next to Man Mo Temple
# 4                Fabulous 2 Bdrm Aprt Open kitchen
#
#                                          description  \
# 0  An ideal Hong location any visitor--hip withou...
# 1  Located steps from Hollywood road, with new ea...
# 2  Located right in the heart of Central, this 2 ...
# 3  <b>The space</b><br />Situated in one of Hong ...
# 4  Nicely decorated, spacious 2 bedroom apartment...
#
#                                neighborhood_overview  \
# 0  In the upper part of trendy, hip Sheung Wan, w...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Sheung Wan neighbourhood is ever changing ...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/84364564/1e0c...   160139
# 1  https://a0.muscache.com/pictures/2873745/90c15...   304876
# 2  https://a0.muscache.com/pictures/815221/056993...   304876
# 3  https://a0.muscache.com/pictures/1947265/ef01a...   544166
# 4  https://a0.muscache.com/pictures/36936441/e4c1...   304876
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/160139  ...                        10.0
# 1  https://www.airbnb.com/users/show/304876  ...                         9.0
# 2  https://www.airbnb.com/users/show/304876  ...                        10.0
# 3  https://www.airbnb.com/users/show/544166  ...                        10.0
# 4  https://www.airbnb.com/users/show/304876  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                f
# 1                   10.0                 9.0     NaN                f
# 2                   10.0                 9.0     NaN                f
# 3                   10.0                 9.0     NaN                t
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             14                                          10
# 2                             14                                          10
# 3                              1                                           1
# 4                             14                                          10
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            4
# 2                                            4
# 3                                            0
# 4                                            4
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.13
# 1                                           0              1.94
# 2                                           0              2.38
# 3                                           0              0.12
# 4                                           0              3.12
#
# [5 rows x 74 columns]

# %% [markdown]
# How many airbnb listings in Hong Kong?

# %%
detail_listing.shape
# Out:
# (7226, 74)

# %%
detail_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7226 non-null   int64
#  1   listing_url                                   7226 non-null   object
#  2   scrape_id                                     7226 non-null   int64
#  3   last_scraped                                  7226 non-null   object
#  4   name                                          7225 non-null   object
#  5   description                                   6844 non-null   object
#  6   neighborhood_overview                         3255 non-null   object
#  7   picture_url                                   7226 non-null   object
#  8   host_id                                       7226 non-null   int64
#  9   host_url                                      7226 non-null   object
#  10  host_name                                     7226 non-null   object
#  11  host_since                                    7226 non-null   object
#  12  host_location                                 7210 non-null   object
#  13  host_about                                    4677 non-null   object
#  14  host_response_time                            6111 non-null   object
#  15  host_response_rate                            6111 non-null   object
#  16  host_acceptance_rate                          5746 non-null   object
#  17  host_is_superhost                             7226 non-null   object
#  18  host_thumbnail_url                            7226 non-null   object
#  19  host_picture_url                              7226 non-null   object
#  20  host_neighbourhood                            6027 non-null   object
#  21  host_listings_count                           7226 non-null   int64
#  22  host_total_listings_count                     7226 non-null   int64
#  23  host_verifications                            7226 non-null   object
#  24  host_has_profile_pic                          7226 non-null   object
#  25  host_identity_verified                        7226 non-null   object
#  26  neighbourhood                                 3255 non-null   object
#  27  neighbourhood_cleansed                        7226 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      7226 non-null   float64
#  30  longitude                                     7226 non-null   float64
#  31  property_type                                 7226 non-null   object
#  32  room_type                                     7226 non-null   object
#  33  accommodates                                  7226 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                7205 non-null   object
#  36  bedrooms                                      5924 non-null   float64
#  37  beds                                          7077 non-null   float64
#  38  amenities                                     7226 non-null   object
#  39  price                                         7226 non-null   object
#  40  minimum_nights                                7226 non-null   int64
#  41  maximum_nights                                7226 non-null   int64
#  42  minimum_minimum_nights                        7226 non-null   int64
#  43  maximum_minimum_nights                        7226 non-null   int64
#  44  minimum_maximum_nights                        7226 non-null   int64
#  45  maximum_maximum_nights                        7226 non-null   int64
#  46  minimum_nights_avg_ntm                        7226 non-null   float64
#  47  maximum_nights_avg_ntm                        7226 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              7226 non-null   object
#  50  availability_30                               7226 non-null   int64
#  51  availability_60                               7226 non-null   int64
#  52  availability_90                               7226 non-null   int64
#  53  availability_365                              7226 non-null   int64
#  54  calendar_last_scraped                         7226 non-null   object
#  55  number_of_reviews                             7226 non-null   int64
#  56  number_of_reviews_ltm                         7226 non-null   int64
#  57  number_of_reviews_l30d                        7226 non-null   int64
#  58  first_review                                  3992 non-null   object
#  59  last_review                                   3992 non-null   object
#  60  review_scores_rating                          3896 non-null   float64
#  61  review_scores_accuracy                        3896 non-null   float64
#  62  review_scores_cleanliness                     3896 non-null   float64
#  63  review_scores_checkin                         3896 non-null   float64
#  64  review_scores_communication                   3896 non-null   float64
#  65  review_scores_location                        3896 non-null   float64
#  66  review_scores_value                           3896 non-null   float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              7226 non-null   object
#  69  calculated_host_listings_count                7226 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7226 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7226 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7226 non-null   int64
#  73  reviews_per_month                             3992 non-null   float64
# dtypes: float64(18), int64(23), object(33)
# memory usage: 4.1+ MB

# %%
filtered_listing = detail_listing[['property_type', 'neighbourhood', 'review_scores_value', 
                        'bathrooms', 'bedrooms', 'price', 'longitude', 'latitude']].copy()
filtered_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        7226 non-null   object
#  1   neighbourhood        3255 non-null   object
#  2   review_scores_value  3896 non-null   float64
#  3   bathrooms            0 non-null      float64
#  4   bedrooms             5924 non-null   float64
#  5   price                7226 non-null   object
#  6   longitude            7226 non-null   float64
#  7   latitude             7226 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 451.8+ KB

# %% [markdown]
# Do we have more apartment or room on airbnbn in Hong Kong?

# %%
filtered_listing['property_type'].value_counts()
# Out:
# Private room in apartment      2354
# Entire apartment               1720
# Private room in condominium     356
# Entire condominium              338
# Entire serviced apartment       306
#                                ...
# Private room in resort            1
# Shared room in cottage            1
# Farm stay                         1
# Private room in igloo             1
# Room in casa particular           1
# Name: property_type, Length: 77, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.xticks(rotation=90)
sns.countplot((filtered_listing)[('property_type')], order = filtered_listing['property_type'].value_counts().index)
plt.show()

# %%
#filtered_listing['entire_unit'] = 
#filtered_listing['entire_unit'] = np.where(filtered_listing['property_type'].str.contains("Entire"), 1, 0)

#filtered_listing['entire_unit'].value_counts()

# %%
(filtered_listing.neighbourhood.value_counts())/(filtered_listing.neighbourhood.count())
#filtered_listing['neighbourhood'].value_counts() #seems like neighbourhood isnt relevant for HK
# Out:
# Hong Kong, Kowloon, Hong Kong                                             0.364055
# Hong Kong, Hong Kong Island, Hong Kong                                    0.283564
# Hong Kong, New Territories, Hong Kong                                     0.063287
# Shenzhen, Guangdong, China                                                0.050077
# Kowloon, Hong Kong                                                        0.030108
#                                                                             ...
# Hong Kong, Hong Kong, Kowloon, Hong Kong                                  0.000307
# Kowloon, Jordan, Yau Ma Tei, Tsim Sha Tsui, Austin, Kowloon, Hong Kong    0.000307
# 香港, 灣仔, Hong Kong                                                         0.000307
# Southern District, Hong Kong Island, Hong Kong                            0.000307
# 荃灣, 新界, Hong Kong                                                         0.000307
# Name: neighbourhood, Length: 235, dtype: float64

# %%
top_50_neighbourhood = filtered_listing.groupby('neighbourhood').count()
top_50_neighbourhood = top_50_neighbourhood.nlargest(50,'property_type')
top_50_neighbourhood
# Out:
#                                               property_type  \
# neighbourhood
# Hong Kong, Kowloon, Hong Kong                          1185
# Hong Kong, Hong Kong Island, Hong Kong                  923
# Hong Kong, New Territories, Hong Kong                   206
# Shenzhen, Guangdong, China                              163
# Kowloon, Hong Kong                                       98
# Hong Kong Island, Hong Kong                              73
# Hong Kong, Hong Kong                                     59
# Tsim Sha Tsui, Kowloon, Hong Kong                        25
# 香港, 九龍, Hong Kong                                        16
# Hong Kong                                                15
# Sheung Wan, Hong Kong                                    15
# Hong Kong, 九龍, Hong Kong                                 14
# New Territories, Hong Kong                               14
# 九龍, Hong Kong                                            12
# 尖沙咀, 九龍, Hong Kong                                       12
# 旺角, 九龍, Hong Kong                                        12
# Jordan, Kowloon, Hong Kong                               11
# Kowloon, New Territories, Hong Kong                      11
# Wan Chai, *, Hong Kong                                   11
# 佐敦, 九龍, Hong Kong                                        11
# Hong Kong Island, New Territories, Hong Kong              9
# Hong Kong, 香港島, Hong Kong                                 8
# Wan Chai, Hong Kong                                       8
# Yau Ma Tei, Kowloon, Hong Kong                            8
# Hong Kong, Montana, Hong Kong                             7
# Mongkok, Kowloon, Hong Kong                               7
# 彌敦道, 九龍, Hong Kong                                        7
# Hong Kong, Hong Kong, To Kwa Wan, Hong Kong               6
# 東涌, 大嶼山, Hong Kong                                        6
# 油麻地, 九龍, Hong Kong                                        6
# Hong Kong , Hong Kong Island, Hong Kong                   5
# Lamma Island, New Territories, Hong Kong                  5
# Sheung Wan, Hong Kong Island, Hong Kong                   5
# Southside, Hong Kong                                      5
# 新界, Hong Kong                                             5
# 香港, Hong Kong                                             5
# Kowloon City District, Hong Kong SAR, China               4
# Kowloon, Hong Kong Island, Hong Kong                      4
# Mong Kok, Kowloon, Hong Kong                              4
# Mui Wo, Lantau Island, Hong Kong                          4
# Sai Ying Pun, Hong Kong Island, Hong Kong                 4
# Tsim Sha Tsui, Hong Kong                                  4
# 佐敦, Kowloon, Hong Kong                                    4
# Causeway Bay, Hong Kong                                   3
# Hk, 香港島, Hong Kong                                        3
# Jordan , Kowloon, Hong Kong                               3
# Lantau Island, New Territories, Hong Kong                 3
# Mid-level, Hong Kong                                      3
# Peng Chau, New Territories, Hong Kong                     3
# SAI YING PUN, Hong kong, Hong Kong                        3
#
#                                               review_scores_value  bathrooms  \
# neighbourhood
# Hong Kong, Kowloon, Hong Kong                                 854          0
# Hong Kong, Hong Kong Island, Hong Kong                        468          0
# Hong Kong, New Territories, Hong Kong                         157          0
# Shenzhen, Guangdong, China                                     99          0
# Kowloon, Hong Kong                                             61          0
# Hong Kong Island, Hong Kong                                    33          0
# Hong Kong, Hong Kong                                           46          0
# Tsim Sha Tsui, Kowloon, Hong Kong                              19          0
# 香港, 九龍, Hong Kong                                              15          0
# Hong Kong                                                      11          0
# Sheung Wan, Hong Kong                                           7          0
# Hong Kong, 九龍, Hong Kong                                       10          0
# New Territories, Hong Kong                                      8          0
# 九龍, Hong Kong                                                   7          0
# 尖沙咀, 九龍, Hong Kong                                             11          0
# 旺角, 九龍, Hong Kong                                              12          0
# Jordan, Kowloon, Hong Kong                                      9          0
# Kowloon, New Territories, Hong Kong                             9          0
# Wan Chai, *, Hong Kong                                         10          0
# 佐敦, 九龍, Hong Kong                                              11          0
# Hong Kong Island, New Territories, Hong Kong                    7          0
# Hong Kong, 香港島, Hong Kong                                       5          0
# Wan Chai, Hong Kong                                             8          0
# Yau Ma Tei, Kowloon, Hong Kong                                  6          0
# Hong Kong, Montana, Hong Kong                                   7          0
# Mongkok, Kowloon, Hong Kong                                     7          0
# 彌敦道, 九龍, Hong Kong                                              1          0
# Hong Kong, Hong Kong, To Kwa Wan, Hong Kong                     6          0
# 東涌, 大嶼山, Hong Kong                                              6          0
# 油麻地, 九龍, Hong Kong                                              4          0
# Hong Kong , Hong Kong Island, Hong Kong                         5          0
# Lamma Island, New Territories, Hong Kong                        4          0
# Sheung Wan, Hong Kong Island, Hong Kong                         5          0
# Southside, Hong Kong                                            1          0
# 新界, Hong Kong                                                   4          0
# 香港, Hong Kong                                                   5          0
# Kowloon City District, Hong Kong SAR, China                     0          0
# Kowloon, Hong Kong Island, Hong Kong                            4          0
# Mong Kok, Kowloon, Hong Kong                                    4          0
# Mui Wo, Lantau Island, Hong Kong                                4          0
# Sai Ying Pun, Hong Kong Island, Hong Kong                       4          0
# Tsim Sha Tsui, Hong Kong                                        4          0
# 佐敦, Kowloon, Hong Kong                                          4          0
# Causeway Bay, Hong Kong                                         3          0
# Hk, 香港島, Hong Kong                                              3          0
# Jordan , Kowloon, Hong Kong                                     3          0
# Lantau Island, New Territories, Hong Kong                       3          0
# Mid-level, Hong Kong                                            3          0
# Peng Chau, New Territories, Hong Kong                           3          0
# SAI YING PUN, Hong kong, Hong Kong                              3          0
#
#                                               bedrooms  price  longitude  \
# neighbourhood
# Hong Kong, Kowloon, Hong Kong                     1007   1185       1185
# Hong Kong, Hong Kong Island, Hong Kong             654    923        923
# Hong Kong, New Territories, Hong Kong              188    206        206
# Shenzhen, Guangdong, China                         159    163        163
# Kowloon, Hong Kong                                  77     98         98
# Hong Kong Island, Hong Kong                         48     73         73
# Hong Kong, Hong Kong                                50     59         59
# Tsim Sha Tsui, Kowloon, Hong Kong                   21     25         25
# 香港, 九龍, Hong Kong                                   16     16         16
# Hong Kong                                           12     15         15
# Sheung Wan, Hong Kong                               15     15         15
# Hong Kong, 九龍, Hong Kong                            11     14         14
# New Territories, Hong Kong                          14     14         14
# 九龍, Hong Kong                                       12     12         12
# 尖沙咀, 九龍, Hong Kong                                  12     12         12
# 旺角, 九龍, Hong Kong                                   12     12         12
# Jordan, Kowloon, Hong Kong                          10     11         11
# Kowloon, New Territories, Hong Kong                 10     11         11
# Wan Chai, *, Hong Kong                              11     11         11
# 佐敦, 九龍, Hong Kong                                   11     11         11
# Hong Kong Island, New Territories, Hong Kong         9      9          9
# Hong Kong, 香港島, Hong Kong                            7      8          8
# Wan Chai, Hong Kong                                  7      8          8
# Yau Ma Tei, Kowloon, Hong Kong                       7      8          8
# Hong Kong, Montana, Hong Kong                        7      7          7
# Mongkok, Kowloon, Hong Kong                          6      7          7
# 彌敦道, 九龍, Hong Kong                                   7      7          7
# Hong Kong, Hong Kong, To Kwa Wan, Hong Kong          6      6          6
# 東涌, 大嶼山, Hong Kong                                   6      6          6
# 油麻地, 九龍, Hong Kong                                   6      6          6
# Hong Kong , Hong Kong Island, Hong Kong              5      5          5
# Lamma Island, New Territories, Hong Kong             4      5          5
# Sheung Wan, Hong Kong Island, Hong Kong              3      5          5
# Southside, Hong Kong                                 5      5          5
# 新界, Hong Kong                                        5      5          5
# 香港, Hong Kong                                        5      5          5
# Kowloon City District, Hong Kong SAR, China          4      4          4
# Kowloon, Hong Kong Island, Hong Kong                 4      4          4
# Mong Kok, Kowloon, Hong Kong                         2      4          4
# Mui Wo, Lantau Island, Hong Kong                     4      4          4
# Sai Ying Pun, Hong Kong Island, Hong Kong            2      4          4
# Tsim Sha Tsui, Hong Kong                             4      4          4
# 佐敦, Kowloon, Hong Kong                               2      4          4
# Causeway Bay, Hong Kong                              3      3          3
# Hk, 香港島, Hong Kong                                   3      3          3
# Jordan , Kowloon, Hong Kong                          2      3          3
# Lantau Island, New Territories, Hong Kong            3      3          3
# Mid-level, Hong Kong                                 2      3          3
# Peng Chau, New Territories, Hong Kong                3      3          3
# SAI YING PUN, Hong kong, Hong Kong                   0      3          3
#
#                                               latitude  entire_unit
# neighbourhood
# Hong Kong, Kowloon, Hong Kong                     1185         1185
# Hong Kong, Hong Kong Island, Hong Kong             923          923
# Hong Kong, New Territories, Hong Kong              206          206
# Shenzhen, Guangdong, China                         163          163
# Kowloon, Hong Kong                                  98           98
# Hong Kong Island, Hong Kong                         73           73
# Hong Kong, Hong Kong                                59           59
# Tsim Sha Tsui, Kowloon, Hong Kong                   25           25
# 香港, 九龍, Hong Kong                                   16           16
# Hong Kong                                           15           15
# Sheung Wan, Hong Kong                               15           15
# Hong Kong, 九龍, Hong Kong                            14           14
# New Territories, Hong Kong                          14           14
# 九龍, Hong Kong                                       12           12
# 尖沙咀, 九龍, Hong Kong                                  12           12
# 旺角, 九龍, Hong Kong                                   12           12
# Jordan, Kowloon, Hong Kong                          11           11
# Kowloon, New Territories, Hong Kong                 11           11
# Wan Chai, *, Hong Kong                              11           11
# 佐敦, 九龍, Hong Kong                                   11           11
# Hong Kong Island, New Territories, Hong Kong         9            9
# Hong Kong, 香港島, Hong Kong                            8            8
# Wan Chai, Hong Kong                                  8            8
# Yau Ma Tei, Kowloon, Hong Kong                       8            8
# Hong Kong, Montana, Hong Kong                        7            7
# Mongkok, Kowloon, Hong Kong                          7            7
# 彌敦道, 九龍, Hong Kong                                   7            7
# Hong Kong, Hong Kong, To Kwa Wan, Hong Kong          6            6
# 東涌, 大嶼山, Hong Kong                                   6            6
# 油麻地, 九龍, Hong Kong                                   6            6
# Hong Kong , Hong Kong Island, Hong Kong              5            5
# Lamma Island, New Territories, Hong Kong             5            5
# Sheung Wan, Hong Kong Island, Hong Kong              5            5
# Southside, Hong Kong                                 5            5
# 新界, Hong Kong                                        5            5
# 香港, Hong Kong                                        5            5
# Kowloon City District, Hong Kong SAR, China          4            4
# Kowloon, Hong Kong Island, Hong Kong                 4            4
# Mong Kok, Kowloon, Hong Kong                         4            4
# Mui Wo, Lantau Island, Hong Kong                     4            4
# Sai Ying Pun, Hong Kong Island, Hong Kong            4            4
# Tsim Sha Tsui, Hong Kong                             4            4
# 佐敦, Kowloon, Hong Kong                               4            4
# Causeway Bay, Hong Kong                              3            3
# Hk, 香港島, Hong Kong                                   3            3
# Jordan , Kowloon, Hong Kong                          3            3
# Lantau Island, New Territories, Hong Kong            3            3
# Mid-level, Hong Kong                                 3            3
# Peng Chau, New Territories, Hong Kong                3            3
# SAI YING PUN, Hong kong, Hong Kong                   3            3

# %% [markdown]
# The above data is not useful in terms giving insight on neighborhood. There are too many "neighborhood" that refer to the same thing and many of them are erroneous.
#
# However, the following plot on the map seems to indicate where these listings are concentrated.

# %%
#Creates a map of Hong Kong.
m = folium.Map(location=[22.34, 114.1], zoom_start = 11)
m.save('index.html')


#Takes the latitude and longitude coordinates and zips them into a form to be plotted.
lat = pd.to_numeric(filtered_listing['latitude'], errors = 'coerce')
lon = pd.to_numeric(filtered_listing['longitude'], errors = 'coerce')

#Zip togethers each list of latitude and longitude coordinates. 
lat_lon = list(zip(lat,lon))


mc = MarkerCluster().add_to(m)
for i in range(0,len(filtered_listing)):
    folium.Marker(location=lat_lon[i]).add_to(mc)

m.save('index.html')
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
